# %% [markdown]
# # **Introduction to Python Programming Language**
# Welcome to the first tutorial of CSC101. In this tutorial, We will learn about the following topics:
# - Variables assignment
# - Data types
# - Print function
# - Arithmetic operators
# - Logical operators

# %% [markdown]
# ### **Problem-01**
#
# Print out your full name, your semester, your ID number, your hobby and your favorite movie name. All of the information should be in separate lines and should appear formatted like below:
#
# **Output:**
# ```
# Full name: Your full name
# ID: Your ID
# Semester: Your semester
# Hobby: Your hobby
# Favorite movie: Movie name
# ```

# %%
# Write your code here

# %% [markdown]
# ### **Problem-02**
#
# Take input from user their name, address, email and phone number. Then print the message given in output, using the above user information. You can use only one print function. Following is the sample input and output:
#
# **Input:**
# ```
# Name: Mahbubul Syeed
# Address: Dohs, Mirpur
# Email: xyz@gmail.com
# Phone: 12345678
# ```
#
# **Output:**
# ```
# Hello Mahbubul Syeed!
# Your address is: Dohs, Mirpur.
# You will receive a confirmation email at: xyz@gmail.com
# and a message to your registered mobile number (12345678).
# ```

# %%
# Write your code here

# %% [markdown]
# ### **Problem-03**
# Write a program to simulate a brief chat with an imaginary friend. You and your     imaginary friend (let’s call it Replika) will have about 8-10 sentences worth of conversation combined. You can hardcode what Replika will say to you in the program, however, you must provide your responses as input using the `input()` function. The entire conversation should be simulated in one run of the program. You are not required to use loops. You must print out the conversation like a dialog, as shown below.
#
# **Output:**
# ```
# Replika: Hey
# Enter your response: Hi there
# You: Hi there
#
# Replika: How are you today?
# Enter your response: I am fine. What about you?
# You: I am fine. What about you?
#
# Replika: I am fine. Thank you!
# Enter your response: Glad to hear it!
# You: Glad to hear it!
#
# … (continue for 3 to 4 more sentences)
# ```

# %%
# Write your code here

# %% [markdown]
# ### **Problem-04**
#
# Suppose that you have gone out to hang out with 5 of your friends. You guys ordered pizza which had N slices. Total price of the pizza is BDT. Y. However, all of you did not share equally e.g. Some ate more slices than the others. And now you’re scratching your heads as the waiter brings you the bill and you don’t know how much each should pay. Write a program that helps you to figure this out.
#
# N and Y should be inputs to the program. After that, the program will ask how many slices each of you ate. Finally, the program will output the amount each should pay. Sample input & output:
#
# **Input:**
# ```
# Enter the number of slices: 12
# Enter the total price of the pizza: 550
# Enter the number of slices you ate: 3
# Enter the number of slices friend 1 ate: 2
# Enter the number of slices friend 2 ate: 3
# Enter the number of slices friend 3 ate: 1
# Enter the number of slices friend 4 ate: 2
# Enter the number of slices friend 5 ate: 1
# ```
#
# **Output:**
# ```
# Calculating, please wait…
#
# You should pay: BDT. 137.49
# Friend 1 should pay: BDT. 91.66
# Friend 2 should pay: BDT. 137.49
# Friend 3 should pay: BDT. 45.83
# Friend 4 should pay: BDT. 91.66
# Friend 5 should pay: BDT. 45.83
# ```

# %%
# Write your code here

# %% [markdown]
# ### **Problem-05**
#
# Make a simple calculator for two numbers. Take two numbers as input and print the result of simple arithmetic between them. Following is the sample input and output:
#
# **Input**
# ```
# Enter Two numbers..
# Enter number 1: 35
# Enter number 2: 45
# ```
#
# **Output:**
# ```
# Addition (35 + 45) = 80
# Subtraction (35 - 45) = -10
# Division (35 / 45) = .777
# Multiplication (35 * 45) = 1575
# ```

# %%
# Write your code here

# %% [markdown]
# ### **Problem-06**
#
# Suppose you have started working on an hourly basis as a librarian in your institution. You want to know how much you will earn a month given that you know how many hours you will work per week and how much you receive per hour. However, whatever amount you earn per month will have 20% of it deducted and that amount will be instead used to pay part of your tuition fees. Write a program that finds out the earnings before and after the deduction. Also find out the yearly earnings (without deduction) and how much of your tuition fees you are paying yourself annually. Assume that there are 4 weeks per month.
#
# **Input:**
# ```
# Enter the number of hours you will work per week: 20
# Enter the amount you earn per hour: BDT. 150
# ```
#
# **Output:**
# ```
# Monthly earning: BDT. 12000
# Monthly earning after deduction: BDT. 9600
# Yearly earning: BDT. 144000
# Amount paid as tuition fees per year: BDT. 28800
# ```

# %%
# Write your code here

# %% [markdown]
# ### **Problem-07**
# Check the outputs by running the following code and justify them:
#
#
# ```python
# True and True
# False and True
# 1 == 1 and 2 == 1
# "test" == "test"
# 1 == 1 or 2 != 1
# True and 1 == 1
# False and 0 != 0
# True or 1 == 1
# "test" == "testing"
# 1 != 0 and 2 == 1
# "y" in "xylophone"
# "test" == 1
# not (True and False)
# not (1 == 1 and 0 != 1)
# not (10 == 1 or 1000 == 1000)
# not (1 != 10 or 3 == 4)
# not ("testing" == "testing" and "Zed" == "Cool Guy")
# 1 == 1 and not ("testing" == 1 or 1 == 0)
# "chunky" == "bacon" and not (3 == 4 or 3 == 3)
# 3 == 3 and not ("testing" == "testing" or "Python" == "Fun")
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem-08**
#
#
# *   What is a correct Python expression for checking to see if a number stored in a variable x is between 0 and 5?
#     1. `x > 0 and < 5`
#     2. `x > 0 or x < 5`
#     3. `x > 0 and x < 5`
#
# *   Which of the following properly expresses the precedence of operators (using parentheses) in the following expression: **5*3 > 10 and 4+6==11**
#     1. `((5*3) > 10) and ((4+6) == 11)`
#     2. `(5*(3 > 10)) and (4 + (6 == 11))`
#     3. `((((5*3) > 10) and 4)+6) == 11`
#     4. `((5*3) > (10 and (4+6))) == 11`

# %%
# Write your code here

# %% [markdown]
# #### **Problem-09**
# If `a = 9, b = 10`, perform `a and b` and `a & b` operations. Describe the difference.

# %%
# Write your code here

# %% [markdown]
# #### **Problem-10**
# For the following code segments, without copying it over to the IDE and running it, find out what will be output to the console. Justify your answer.
# 1. Segment 01:
#     ```python
#     a = True
#     b = False
#     c = True
#     d = False
#
#     print(not b or c and d)
#     print(not (b and d) or not (not (a and c)) and not c)
#     ```
# 2. Segment 02:
#     ```python
#     a = 1
#     b = 2
#     c = 3
#     d = 11
#
#     print((d%c)**b)
#     print((a + b > c) or (b < c))
#     ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem-11**
# Fill up the following table with correct answers.
#
# | A | B | not A | not B | A == B | A != b | A or B | A and B|
# |---|---|:-------:|:-------:|:--------:|:--------:|:--------:|:--------:|
# | True | False |  ?  | ?  |  ?  |   ?  |   ?  |  ?  |
# | False | True |  ?  | ?  |  ?  |   ?  |   ?  |  ?  |
# | True | True |  ?  | ?  |  ?  |   ?  |   ?  |  ?  |
# | False | False |  ?  | ?  |  ?  |   ?  |   ?  |  ?  |

# %%
# Write your code here

# %% [markdown]
# #### **Problem-12**
# Write a Python program to calculate the sum of all digits of a $4$ digit number. Suppose the input number is $1024$. So the output will be $1+0+2+4 = 7$.

# %%
# Write your code here

# %% [markdown]
# ### **Problem-13**
# Write a program that takes 5 numbers as input. Display the following information:
#
# 1.   Sum of the numbers
# 2.   Average of the numbers
# 3.   The quotient of the first number divided by the fifth number
# 4.   The product of the second number with the fourth number divided by the third number
# 5.    (True/False) If any of the numbers are greater than 5
# 6. (True/False) If all of the numbers are divisible by 13
# 7. (True/False) If any of the numbers is equal to 42

# %%
# Write your code here
